# %%
import os
os.chdir('..')
import requests
import icepyx as ipx

# %% [markdown]
# ### Get ATL03 and ATL06 data corresponding to pine island region

# %%
## Configure
earthdata_uid = '411795604'  # for earthdata website login
email = 'xinluo_xin@163.com'
short_name_atl03 = 'ATL03'
spatial_extent = [-102, -76, -98, -74.5]     # pine island
date_range = ['2019-01-01','2019-6-30']
path_down_data = 'data/icesat2/pineisland_atl03'

# %%
region_sel = ipx.Query(short_name_atl03, spatial_extent, date_range)
# region_sel = ipx.Query(short_name_atl06, spatial_extent, date_range)
region_sel.visualize_spatial_extent()
print(region_sel.avail_granules())
# Out:
# {'Number of available granules': 93, 'Average size of granules (MB)': 941.614764049488, 'Total size of all granules (MB)': 87570.17305660243}

# %%
# earthdata user login and data download
region_sel.earthdata_login(earthdata_uid, email)
region_sel.order_granules(email=False)
region_sel.download_granules(path=path_down_data, verbose=False, subset=True)
# Out:
# Total number of data order requests is  10  for  93  granules.
# Data request  1  of  10  is submitting to NSIDC
# order ID:  5000001469238
# Initial status of your order request at NSIDC is:  processing
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# Your order status is still  processing  at NSIDC. Please continue waiting... this may take a few moments.
# ...
